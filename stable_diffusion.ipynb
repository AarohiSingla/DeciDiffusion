# %%
# !pip install diffusers --upgrade
# !pip install invisible_watermark transformers accelerate safetensors
#!pip install matplotlib

# %%
import torch
import os
import time
from IPython.core.display import display, HTML

from matplotlib import pyplot as plt
from tqdm.notebook import tqdm
from diffusers import StableDiffusionPipeline

import os
import torch
from matplotlib import pyplot as plt
from tqdm.notebook import tqdm
import time
# Out:
# C:\Users\f\AppData\Local\Temp\ipykernel_11772\2044984847.py:4: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
stable_diffusion_pipeline = StableDiffusionPipeline.from_pretrained('runwayml/stable-diffusion-v1-5',
                                                                    torch_dtype=torch.float16)
stable_diffusion_pipeline = stable_diffusion_pipeline.to("cuda")
# Out:
# ...
# text_encoder\model.safetensors not found
# ...
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.

# %%
def text_to_image(pipeline, prompt):

    # Start the timer
    start_time = time.time()

    # Call the pipeline function directly
    result = pipeline([prompt], generator=torch.Generator("cuda").manual_seed(42))

    # Calculate and print the elapsed time
    elapsed_time = time.time() - start_time
    display(HTML(f'<span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: {elapsed_time:.2f} seconds</span>'))

    img = result.images[0]

    filename = prompt.replace(' ', '_')
    if len(filename) > 100:  # Limit filename to 100 characters
        filename = filename[:100]

    # Incorporate the pipeline's class name into the filename
    pipeline_name = pipeline.__class__.__name__
    #save_path = os.path.join("/content", f"{pipeline_name}_{filename}.png")
    save_path = os.path.join("D:/deciDiffusion", f"{pipeline_name}_{filename}.png")
    img.save(save_path)

    # Display the saved image
    plt.imshow(img)
    plt.axis('off')
    plt.show()
    return save_path

# %%
text_to_image(stable_diffusion_pipeline, "Create an image of a picturesque Indian village with thatched-roof huts, and lush fields")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 11.26 seconds</span>
# 'D:/deciDiffusion\\StableDiffusionPipeline_Create_an_image_of_a_picturesque_Indian_village_with_thatched-roof_huts,_and_lush_fields.png'

# %%
text_to_image(stable_diffusion_pipeline, "Illustrate a serene view of the Ganges River at Varanasi, with ghats, pilgrims, and the evening Ganga Aarti.")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 4.65 seconds</span>
# 'D:/deciDiffusion\\StableDiffusionPipeline_Illustrate_a_serene_view_of_the_Ganges_River_at_Varanasi,_with_ghats,_pilgrims,_and_the_evening_Gang.png'

# %%
text_to_image(stable_diffusion_pipeline, "Create a colorful image capturing the spirit of the Holi festival, with people throwing vibrant powdered colors.")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 4.81 seconds</span>
# 'D:/deciDiffusion\\StableDiffusionPipeline_Create_a_colorful_image_capturing_the_spirit_of_the_Holi_festival,_with_people_throwing_vibrant_powd.png'

# %%
text_to_image(stable_diffusion_pipeline, "Illustrate a meditative scene of a yogi practicing yoga amidst the serene beauty of the Himalayan mountains.")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 4.87 seconds</span>
# 'D:/deciDiffusion\\StableDiffusionPipeline_Illustrate_a_meditative_scene_of_a_yogi_practicing_yoga_amidst_the_serene_beauty_of_the_Himalayan_mo.png'

# %%
text_to_image(stable_diffusion_pipeline, "a water color painting of the Golden Temple awash in the glow of morning light with a vanilla sky")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 4.87 seconds</span>
# 'D:/deciDiffusion\\StableDiffusionPipeline_a_water_color_painting_of_the_Golden_Temple_awash_in_the_glow_of_morning_light_with_a_vanilla_sky.png'

# %%
text_to_image(stable_diffusion_pipeline, "a realistic portrait of albert einstein with a bewildered expression")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 4.88 seconds</span>
# 'D:/deciDiffusion\\StableDiffusionPipeline_a_realistic_portrait_of_albert_einstein_with_a_bewildered_expression.png'

# %%
text_to_image(stable_diffusion_pipeline, "Emma Watson as a powerful mysterious sorceress, casting lightning magic, detailed clothing")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 4.80 seconds</span>
# 'D:/deciDiffusion\\StableDiffusionPipeline_Emma_Watson_as_a_powerful_mysterious_sorceress,_casting_lightning_magic,_detailed_clothing.png'

# %%
text_to_image(stable_diffusion_pipeline, "Create an enchanting underwater scene featuring a graceful mermaid with long, flowing hair, surrounded by colorful coral reefs, exotic fish, and sparkling sea treasures.")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 5.80 seconds</span>
# 'D:/deciDiffusion\\StableDiffusionPipeline_Create_an_enchanting_underwater_scene_featuring_a_graceful_mermaid_with_long,_flowing_hair,_surround.png'

# %%
text_to_image(stable_diffusion_pipeline, "Generate an image of a serene Japanese garden with a koi pond and cherry blossoms.")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 5.64 seconds</span>
# 'D:/deciDiffusion\\StableDiffusionPipeline_Generate_an_image_of_a_serene_Japanese_garden_with_a_koi_pond_and_cherry_blossoms..png'

# %%
text_to_image(stable_diffusion_pipeline, "Visualize a peaceful beach at sunset with gentle waves and a colorful sky.")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 5.72 seconds</span>
# 'D:/deciDiffusion\\StableDiffusionPipeline_Visualize_a_peaceful_beach_at_sunset_with_gentle_waves_and_a_colorful_sky..png'
